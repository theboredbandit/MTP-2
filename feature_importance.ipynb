# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
from matplotlib import pyplot as plt

# %%
features=['Within office hour' ,'Duration from office start' ,
'Duration from office end' , 'Within office break hour' , 'Duration from office break start' , 'Duration from office break end' ,
'Elapsed time from last reported 0' , 'Elapsed time from last reported 1' , 'Did the user report?']

# %%
#Valence
users=[12,13,14,15,16,17,18,19,20,23,25,26,29,32,33,36,37]
imp_all={}
for id in users:
  dataset = pd.read_csv('Tap/Valence/user_' + str(id) + '.csv')
  if len(dataset)==0:
    continue
  dataset.drop('Sample id', inplace=True, axis=1) #removing the sample id column
  dataset.replace('Yes',1,inplace=True)
  dataset.replace('No',0,inplace=True)
  X=dataset.iloc[:,:-1]
  y=dataset.iloc[:,-1:]
  print(X.head())
  print(y.head())
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

  rf = RandomForestClassifier(n_estimators=150)
  rf.fit(X_train, y_train)

  sort = rf.feature_importances_.argsort()
  j=0
  imp={}
  for item in rf.feature_importances_:
    imp[features[j]]=item
    j+=1
  imp_all[id]=imp
  print("id=",id)
  print(sort)
# Out:
#    Within office hour  Duration from office start  Duration from office end  \
# 0                   1                       415.0                   43615.0
# 1                   1                       401.0                   43601.0
# 2                   0                     33728.0                   76928.0
# 3                   0                     33718.0                   76918.0
# 4                   1                       488.0                   42712.0
#
#    Within office break hour  Duration from office break start  \
# 0                         0                             415.0
# 1                         0                             401.0
# 2                         0                           33728.0
# 3                         0                           33718.0
# 4                         1                             488.0
#
#    Duration from office break end  Elapsed time from last reported 0  \
# ...

# %%
print(imp_all)
# Out:
# {12: {'Within office hour': 0.00449883062923137, 'Duration from office start': 0.1503857867473193, 'Duration from office end': 0.16023178964886775, 'Within office break hour': 0.006756534879014747, 'Duration from office break start': 0.16157661292516262, 'Duration from office break end': 0.165420217900453, 'Elapsed time from last reported 0': 0.16830782811212935, 'Elapsed time from last reported 1': 0.18282239915782192}, 13: {'Within office hour': 0.005348702023318873, 'Duration from office start': 0.15652127410461505, 'Duration from office end': 0.1631709725654007, 'Within office break hour': 0.0017694634512622027, 'Duration from office break start': 0.16248795575976407, 'Duration from office break end': 0.16040985920547174, 'Elapsed time from last reported 0': 0.1785717038474859, 'Elapsed time from last reported 1': 0.1717200690426815}, 14: {'Within office hour': 0.006163491518484786, 'Duration from office start': 0.1516804400959652, 'Duration from office end': 0.15461212345752173,
# ...

# %%
#Arousal
users=[12,13,14,15,16,17,18,19,20,23,25,26,29,32,33,36,37]
imp_all={}
for id in users:
  dataset = pd.read_csv('Tap/Arousal/user_' + str(id) + '.csv')
  if len(dataset)==0:
    continue
  dataset.drop('Sample id', inplace=True, axis=1) #removing the sample id column
  dataset.replace('Yes',1,inplace=True)
  dataset.replace('No',0,inplace=True)
  X=dataset.iloc[:,:-1]
  y=dataset.iloc[:,-1:]
  print(X.head())
  print(y.head())
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

  rf = RandomForestClassifier(n_estimators=150)
  rf.fit(X_train, y_train)

  sort = rf.feature_importances_.argsort()
  j=0
  imp={}
  for item in rf.feature_importances_:
    imp[features[j]]=item
    j+=1
  imp_all[id]=imp
  print("id=",id)
  print(sort)
# Out:
#    Within office hour  Duration from office start  Duration from office end  \
# 0                   1                      8923.0                   34277.0
# 1                   1                      8941.0                   34259.0
# 2                   1                      5226.0                   48426.0
# 3                   1                      5174.0                   48374.0
# 4                   1                     16732.0                   26468.0
#
#    Within office break hour  Duration from office break start  \
# 0                         1                            8923.0
# 1                         1                            8941.0
# 2                         0                            5226.0
# 3                         0                            5174.0
# 4                         1                           16732.0
#
#    Duration from office break end  Elapsed time from last reported 0  \
# ...

# %%
print(imp_all)
# Out:
# {12: {'Within office hour': 0.00444750906325178, 'Duration from office start': 0.1648436710807513, 'Duration from office end': 0.1539975395528264, 'Within office break hour': 0.0058902475687973195, 'Duration from office break start': 0.16005567251648914, 'Duration from office break end': 0.15785401263738638, 'Elapsed time from last reported 0': 0.17003032567845833, 'Elapsed time from last reported 1': 0.18288102190203936}, 13: {'Within office hour': 0.004610978812774903, 'Duration from office start': 0.15651524610579862, 'Duration from office end': 0.16432848398758831, 'Within office break hour': 0.0026657279256167986, 'Duration from office break start': 0.15901821559425022, 'Duration from office break end': 0.15985141094772665, 'Elapsed time from last reported 0': 0.17701599905422946, 'Elapsed time from last reported 1': 0.17599393757201515}, 14: {'Within office hour': 0.0027780942357009163, 'Duration from office start': 0.15437983128024546, 'Duration from office end': 0.15490343467
# ...
